# %%
### Data Ingestion

# %%
### document structure
from langchain_core.documents import Document

# %%
doc=Document(
    page_content= "this is the main text content i am using to create rag",
    metadata={
        "source":"hello.txt",
        "page":1,
        "author":"krish naik"
    }
)
doc
# Out:
# Document(metadata={'source': 'hello.txt', 'page': 1, 'author': 'krish naik'}, page_content='this is the main text content i am using to create rag')

# %%
##create a txt file
import os 
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":""" Python is a high-level, general-purpose programming language created by Guido van Rossum and first released in 1991. It is widely celebrated for its simplicity, readability, and versatile ecosystem, making it a top choice for beginners and professionals alike in 2026. 
W3Schools
W3Schools
 +2
Core Characteristics
Simple & Readable: Its syntax mimics natural English, allowing you to write concepts in fewer lines of code compared to languages like Java or C++.
Interpreted: Python executes code line-by-line, which makes debugging faster since errors are reported as they occur.
Multi-Paradigm: It supports various programming styles, including object-oriented, procedural, and functional programming.
Dynamically Typed: You don't need to declare variable types (like int or string) explicitly; Python determines them at runtime.
Batteries Included: It comes with a massive standard library that handles everything from file I/O to internet protocols out of the box""",
"../data/text_files/machine_learning.txt":"""Machine learning (ML) is a subset of artificial intelligence (AI) that enables systems to learn from data, identify patterns, and make decisions or predictions without explicit programming. By training algorithms on large datasets, models improve their accuracy over time, powering applications like recommendation engines, fraud detection, and autonomous vehicles. 
IBM
IBM
 +4
Key components of machine learning include: """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8")as f:
        f.write(content)
print("💋 sample text .........bn gya hai 💋")
# Out:
# 💋 sample text .........bn gya hai 💋

# %%
##text loader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content=" Python is a high-level, general-purpose programming language created by Guido van Rossum and first released in 1991. It is widely celebrated for its simplicity, readability, and versatile ecosystem, making it a top choice for beginners and professionals alike in 2026. \nW3Schools\nW3Schools\n +2\nCore Characteristics\nSimple & Readable: Its syntax mimics natural English, allowing you to write concepts in fewer lines of code compared to languages like Java or C++.\nInterpreted: Python executes code line-by-line, which makes debugging faster since errors are reported as they occur.\nMulti-Paradigm: It supports various programming styles, including object-oriented, procedural, and functional programming.\nDynamically Typed: You don't need to declare variable types (like int or string) explicitly; Python determines them at runtime.\nBatteries Included: It comes with a massive standard library that handle
# ...

# %%
##directorry Loader

from langchain_community.document_loaders import DirectoryLoader

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False)#pattern match


documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content=" Python is a high-level, general-purpose programming language created by Guido van Rossum and first released in 1991. It is widely celebrated for its simplicity, readability, and versatile ecosystem, making it a top choice for beginners and professionals alike in 2026. \nW3Schools\nW3Schools\n +2\nCore Characteristics\nSimple & Readable: Its syntax mimics natural English, allowing you to write concepts in fewer lines of code compared to languages like Java or C++.\nInterpreted: Python executes code line-by-line, which makes debugging faster since errors are reported as they occur.\nMulti-Paradigm: It supports various programming styles, including object-oriented, procedural, and functional programming.\nDynamically Typed: You don't need to declare variable types (like int or string) explicitly; Python determines them at runtime.\nBatteries Included: It comes with a massive standard library that handle
# ...

# %%
##directorry Loader
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader

dir_loader2=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    # loader_kwargs={'encoding':'utf-8'},
    show_progress=False)#pattern match


pdf_documents=dir_loader2.load()
pdf_documents
# Out:
# [Document(metadata={'producer': '', 'creator': 'Microsoft Word', 'creationdate': '2026-04-09T02:20:50-07:00', 'source': '../data/pdf/123103062_123103065.pdf', 'file_path': '../data/pdf/123103062_123103065.pdf', 'total_pages': 3, 'format': 'PDF 1.7', 'title': '', 'author': 'Adigoppula chandana sree', 'subject': '', 'keywords': '', 'moddate': '2026-04-09T02:20:50-07:00', 'trapped': '', 'modDate': "D:20260409022050-07'00'", 'creationDate': "D:20260409022050-07'00'", 'page': 0}, page_content='Lab 11: Experiments using SPARK \n \n1)Write a program to find average marks of students. \nval data = sc.parallelize(List( \n  ("ram", 80), \n  ("hema", 70), \n  ("raju", 90), \n  ("hema", 20), \n  ("gopi", 70) \n)) \n  \n// (name, (marks, count)) \nval sumCount = data.mapValues(mark => (mark, 1)) \n                   .reduceByKey{ case ((sum1, c1), (sum2, c2)) => \n                     (sum1 + sum2, c1 + c2) \n                   } \n  \n// average = sum / count \nval averages = sumCount.mapValues{
# ...

# %%
from langchain_community.document_loaders import CSVLoader

csv_loader = DirectoryLoader(
    "../data/csv",
    glob="**/*.csv",
    loader_cls=CSVLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False,
)

csv_documents = csv_loader.load()
for doc in csv_documents:
    print(doc)
# Out:
# page_content='Unnamed: 0: 0
# verse: This phenomenal creation, which is both ephemeral and eternal, is like a tree, but having its seed above in the Highest and its ramifications on this earth below. The scriptures are its leaves, and he who understands this, knows.
# predicted_labels: awe
# predicted_scores: 0.813607991' metadata={'source': '../data/csv/all_results 2.csv', 'row': 0}
# page_content='Unnamed: 0: 1
# verse: Its branches shoot upwards and downwards, deriving their nourishment from the Qualities; its buds are the objects of sense; and its roots, which follow the Law causing manâs regeneration and degeneration, pierce downwards into the soil.
# predicted_labels: hope, awe
# predicted_scores: 0.7271633744239807, 0.6616836786270142' metadata={'source': '../data/csv/all_results 2.csv', 'row': 1}
# page_content='Unnamed: 0: 2
# ...
